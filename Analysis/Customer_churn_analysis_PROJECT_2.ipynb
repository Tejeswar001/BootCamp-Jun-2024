# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejeswar001/BootCamp-Jun-2024/blob/BootCampProgress/Analysis/Customer_churn_analysis_PROJECT_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Customer churn

# %% [markdown]
# `customer churn` refers to the phenomenon of customers stopping their subscriptions or relationships with a company.
#
#
# If the value in the 'Churn' column is 'Yes', it means that the specific customer has churned - they have stopped using the company's services or products.
#
#
# "churn" refers to the rate at which customers stop doing business with a company. It's essentially the opposite of customer retention.
#
# For example, in a subscription-based service, churn happens when customers cancel their subscriptions.
#
# High churn rates can be detrimental to a business as it indicates customer dissatisfaction and loss of revenue.
#
# In the context of a telecommunications customer churn dataset, the columns "Partner" and "Dependents" likely refer to the following:
#
# - Partner: Indicates whether the customer has a partner (spouse or significant other) living with them. The values would typically be "Yes" or "No".
#
# - Dependents: Indicates whether the customer has any dependents (children or others) who rely on them. The values would also typically be "Yes" or "No".

# %% [markdown]
# ## Import all necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
print(df)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ## Study Data

# %%
print(df.head())
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
print(df.describe())
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# The `'tenure'` column in the customer churn CSV file represents the number of months a customer has stayed with the company. It's a key feature for understanding churn, as customers with longer tenure are often considered more loyal and less likely to leave.

# %% [markdown]
# ## NULL values

# %%
print(df.isnull().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# 0 null values in the csv file

# %%
print(df.columns)
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
int_cols = df.select_dtypes(include=['int64','float64']).columns
print(int_cols)
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges'], dtype='object')

# %% [markdown]
# ### DataType of TotalCharges

# %%
print(df['TotalCharges'].dtype)
# Out:
# object

# %% [markdown]
# - TotalCharges Should be float.
# - So, Let's change it.

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %% [markdown]
# Check the data type again

# %%
print(df['TotalCharges'].dtype)
# Out:
# float64

# %% [markdown]
# Now, Check for the null values

# %%
print(df['TotalCharges'].isnull().sum())
# Out:
# 11

# %%
print(df[df['TotalCharges'].isnull()])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %% [markdown]
# After studying the above output we can see the `tenure` column is of 0,
#
# **Conclusion**
# - *New Customers*: A `tenure` of 0 typically indicates customers who just signed up.
# - *No Billing Cycle*: It's logical that new customers with `zero tenure` wouldn't have a 'TotalCharges' value yet, as they haven't completed a billing cycle.

# %%
df['TotalCharges'] = df['TotalCharges'].fillna(0)

# %%
print(df['TotalCharges'].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Identify Outliers in the Data

# %%
sns.boxplot(x=df['tenure'])
plt.show()

# %% [markdown]
# It's important to clarify whether values of `0 and 70` in the `'tenure'` column are actually outliers or just the minimum and maximum values in your dataset. Customers with 0 tenure might be new customers who just signed up, and customers with 70 months tenure might be your most loyal long-term customers.

# %%
sns.scatterplot(x=df['tenure'], y=df['tenure'].value_counts())
plt.show()

# %%
sns.histplot(df['tenure'])
plt.show()

# %%
sns.boxplot(x=df['MonthlyCharges'])
plt.show()

# %%
sns.histplot(df['MonthlyCharges'])
plt.show()

# %% [markdown]
# - As perthe histogram the count around 20 is high, perhaps 29.85 represents a basic plan

# %%
sns.histplot(df['SeniorCitizen'])
plt.title('Senior Citizen Count')
plt.show()

# %% [markdown]
# - Count of senior Citizens < Count of Non-Senior Citizens

# %% [markdown]
# # Analysis

# %% [markdown]
# ## Univar Analysis

# %% [markdown]
# ### Overall Churn Rate

# %%
total_customers = 5174 + 1869
churned_customers = 1869

overall_churn_rate = (churned_customers / total_customers) * 100
print("Overall Churn Rate: {:.1f}%".format(overall_churn_rate))
# Out:
# Overall Churn Rate: 26.5%

# %% [markdown]
# Univariate analysis is a statistical method that focuses on analyzing each variable in a dataset individually.
#
# It involves examining the distribution of a single variable.

# %%
variables = df.columns
print(variables)
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# ### Contract column analysis

# %%
contract_count = df['Contract'].value_counts()
print(contract_count)
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.pie(contract_count, labels=contract_count.index, autopct='%1.1f%%',startangle=90)
plt.title('Contract')
plt.show()

# %% [markdown]
# **Conclusion**
# - From the pie chart, we can say that `Month-to-month` is the popular contract and followed by `Two year` contract and `one year` contract

# %% [markdown]
# ### Internet Service

# %%
plt.figure(figsize=(8,7))
plt.pie(df['InternetService'].value_counts(),labels=df['InternetService'].value_counts().index,autopct='%1.1f%%',startangle=90)
plt.title('Internet Service')
plt.show()

# %% [markdown]
# Based on the distribution of internet service types, it's clear that Fiber optic is the most popular choice among customers, capturing nearly half (44%) of the market share. DSL comes in second with a respectable 34.4%, indicating a significant portion of customers still rely on this technology. However, a notable 21.7% of customers opt for no internet service at all.
#
# **Possible Implications and Further Considerations:**
#
# - Fiber Optic Growth: The strong preference for Fiber optic suggests a growing demand for high-speed internet, likely driven by trends like streaming, gaming, and increased reliance on internet-based services.
# - DSL Retention: While DSL remains a significant player, it might face challenges in retaining customers as Fiber optic becomes more accessible and affordable.
# - Unconnected Customers: The substantial portion of customers without internet service raises questions about potential barriers to adoption, such as cost, availability, or lack of perceived need. Understanding these factors could be crucial for expanding market reach.

# %% [markdown]
# ## Bivar Analysis

# %% [markdown]
# `Bivariate analysis` is a statistical method that examines the relationship between two variables. It explores if and how two variables are associated or correlated with each other.

# %%
variables = df.columns
print(variables)
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %% [markdown]
# **`Gender column analysis`**

# %%
gender_counts = df['gender'].value_counts()
print(gender_counts)
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %% [markdown]
# Now, let's calculate the frequency of the gender who has `churned`(stoped using service).

# %% [markdown]
# ### Gender vs Churn

# %%
churn_gender_count = df[df['Churn']=='Yes']['gender'].value_counts()
print(churn_gender_count)
# Out:
# gender
# Female    939
# Male      930
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.pie(churn_gender_count, labels=churn_gender_count.index, autopct='%1.1f%%',startangle=90)
plt.title('Churn by Gender')
plt.show()

# %% [markdown]
# **Conclusion**
# - There is no significant difference in the number of male and female customers, perhaps there is no bias.
# - So, no gender specific churn.

# %% [markdown]
# ### Payment Method vs Churn

# %% [markdown]
# `Objective`: Assess if the payment method affects customer churn.

# %%
print(df['PaymentMethod'].value_counts())
# Out:
# PaymentMethod
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,7))
sns.histplot(data=df,x='PaymentMethod',hue='Churn',multiple="dodge",shrink=.7)
plt.title('Payment Method vs Churn')
plt.ylim(0,1500)
plt.show()

# %% [markdown]
# **Conclusion**
# - `Electronic check` payment method customers have higher churn.
# - `Mailed check` payment method customers have lower churn.

# %% [markdown]
# ### Senior citizen vs Churn

# %%
print(df['SeniorCitizen'].value_counts())
# Out:
# SeniorCitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,4))
sns.histplot(data=df,x='SeniorCitizen',hue='Churn',multiple="dodge",shrink=.999)
plt.title('Senior Citizen vs Churn')
plt.show()

# %% [markdown]
# > Let's find the percentage of senior citizens who are churned and who are not.

# %%
churned_seniors = df[df['SeniorCitizen']==1]['Churn'].value_counts()
print(churned_seniors)
# Out:
# Churn
# No     666
# Yes    476
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.pie(churned_seniors,labels=churned_seniors.index,autopct='%1.1f%%',startangle=90)
plt.title('Churned Senior Citizens')
plt.show()

# %% [markdown]
# **Conclusion**
# - Almost `6 out 10` senior citizens continue to use the service.
# - `However, the churn rate for seniors is still considerable.`The fact that over 40% of seniors churn indicates there might be specific factors affecting this group that need to be addressed.

# %% [markdown]
# ### Phone Services vs Churn

# %% [markdown]
# Why Analyze Phone Service vs Churn?
#
#
# **we conduct this analysis to examine the relationship between phone service and churn**
# - we can determine if the phone service lack any significant factor driving customers to leave.
# - Understanding the impact of phone services on churn can alter the services and meet the customer satisfaction.
#
# **Let's talk about the `Benefits` of the analysis**
# - We can focus upon the customer churn rates and the causing issues.
# -  Retaining customers who might have churned due to lack of phone services can lead to increased revenue and customer lifetime value.

# %%
plt.figure(figsize=(8,7))
sns.histplot(x=df['PhoneService'],hue=df['Churn'],multiple="dodge",shrink=.8)
plt.title('Phone Service vs Churn')
plt.show()

# %% [markdown]
# **Now let's break the things up**
# - "Let's analyze the churn behavior of customers who did not subscribe to phone services."
# - "Similarly, let's examine the churn patterns among customers who opted for phone services."

# %%
churn_phone = df[df['PhoneService']=='Yes']['Churn'].value_counts()
print(churn_phone)
# Out:
# Churn
# No     4662
# Yes    1699
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,7))
plt.pie(churn_phone,labels=churn_phone.index,autopct='%1.1f%%',startangle=90)
plt.title('Phone Service Churn')
plt.show()

# %%
nophone_churn = df[df['PhoneService']=='No']['Churn'].value_counts()
print(nophone_churn)
# Out:
# Churn
# No     512
# Yes    170
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,7))
plt.pie(nophone_churn,labels=nophone_churn.index,autopct='%1.1f%%',startangle=90)
plt.title('No Phone Service Churn')
# Out:
# Text(0.5, 1.0, 'No Phone Service Churn')

# %% [markdown]
# **Observation**:
#
#  The percentage of customers who churned, appears to be similar for both those with and without phone service.
#
# However, we cannot definitively conclude that phone service is not a factor influencing churn.

# %% [markdown]
# ### Internet Services vs Churn

# %% [markdown]
# **Reasons for Churn Analysis (Internet Service)**:
#
# - Determine if specific internet service types (DSL, Fiber optic, etc.) are correlated with higher churn rates.
# - Identify potential issues with certain internet service offerings.
# - Understand customer preferences and satisfaction levels regarding internet services.
#
# **Benefits of this Analysis:**
#
# - Targeted Improvements: Address specific pain points related to internet services to reduce churn.
# - Customer Retention: Proactively retain customers who might be considering leaving due to dissatisfaction with internet services.
# - Competitive Advantage: Offer superior internet service options compared to competitors.
# - Increased Revenue: Reduce customer churn and potentially upsell higher-tier internet packages.

# %%
print(df['InternetService'].value_counts())
# Out:
# InternetService
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,7))
sns.histplot(x=df['InternetService'],hue=df['Churn'],multiple="dodge",shrink=.8)
plt.title('Internet Service vs Churn')
plt.show()

# %% [markdown]
# **From graph let's understand the relationship between 'Fiber Optic' Internet Service  and Customer churn**

# %%
plt.figure(figsize=(8,7))
plt.pie(df[df['InternetService']=='Fiber optic']['Churn'].value_counts(),labels=df[df['InternetService']=='Fiber optic']['Churn'].value_counts().index,autopct='%1.1f%%',startangle=90)
plt.title('FiberOptic vs Churn')
plt.show()

# %% [markdown]
# ### StreamingMovies vs Churn

# %% [markdown]
# **Reasons for Churn Analysis (Streaming Services):**
#
# - `Identify Correlation`: Determine if subscribing to streaming movies is associated with higher or lower churn rates. This helps understand if the streaming service is a factor in customer satisfaction.
# - `Content and Quality`: Assess if churn is related to the content library or streaming quality. This can reveal areas for improvement in the streaming service offering.
#
# **Benefits of this Analysis:**
#
# - `Targeted Retention Strategies`: Develop specific retention strategies for customers who churn due to dissatisfaction with streaming services.
# - `Service Enhancement`: Identify areas for improvement in content, streaming quality, or pricing to reduce churn and increase customer satisfaction.

# %%
print(df['StreamingMovies'].value_counts())
# Out:
# StreamingMovies
# No                     2785
# Yes                    2732
# No internet service    1526
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,7))
sns.histplot(x=df['StreamingMovies'],hue=df['Churn'],multiple="dodge",shrink=.8)
plt.title('Streaming Movies vs Churn')
plt.show()

# %%
plt.figure(figsize=(8,7))
plt.pie(df[df['StreamingMovies']=='Yes']['Churn'].value_counts(),labels=df[df['StreamingMovies']=='Yes']['Churn'].value_counts().index,autopct='%1.1f%%',startangle=90)
plt.title('Streaming Movies Churn')
plt.show()

# %% [markdown]
# **Conclusion:** While a majority `(70.1%)` of customers who opted for streaming movies remained with the service, a significant portion `(29.9%)` churned. This suggests that while streaming movies might be a valued service for many, it may not be a strong enough factor to prevent churn for almost a third of these customers.

# %%
plt.figure(figsize=(8,7))
plt.pie(df[df['StreamingMovies']=='No']['Churn'].value_counts(),labels=df[df['StreamingMovies']=='No']['Churn'].value_counts().index,autopct='%1.1f%%',startangle=90)
plt.title('No Streaming Movies Churn')
plt.show()

# %% [markdown]
# **Conclusion:** A notable portion `(33.7%)` of customers who did not opt for streaming movies churned, compared to `66.3%` who did not. `This suggests that the absence of a streaming movies service might be a contributing factor to churn for some customers.` *However, it's important to note that the churn rate for customers with streaming movies (29.9%) isn't drastically different.* Therefore, while the availability of streaming movies might play a role in customer retention, it's likely not the sole determining factor, and other variables are also at play.

# %% [markdown]
# ### Streaming Tv vs Churn

# %% [markdown]
# **Reasons for Streaming TV vs Churn Analysis:**
#
# - **Identify Service Impact**: Determine if the availability and quality of streaming TV services are correlated with customer churn.
# - **Understand Customer Preferences**: Gain insights into customer preferences for streaming TV content and features.
# - **Pinpoint Potential Issues**: Identify any specific issues or dissatisfaction related to the streaming TV service that might be driving churn.

# %%
print(df['StreamingTV'].value_counts())
# Out:
# StreamingTV
# No                     2810
# Yes                    2707
# No internet service    1526
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,7))
sns.histplot(x=df['StreamingTV'],hue=df['Churn'],multiple="dodge",shrink=.8)
plt.title('Streaming TV vs Churn')
plt.show()

# %%
plt.figure(figsize=(8,7))
plt.pie(df[df['StreamingTV']=='No']['Churn'].value_counts(),labels=df[df['StreamingTV']=='No']['Churn'].value_counts().index,autopct='%1.1f%%',startangle=90)
plt.title('No Streaming TV Churn')
plt.show()

# %% [markdown]
# **Conclusion**: A significant portion `(33.5%)` of customers who did not opt for streaming TV churned, compared to `66.5%` who did not. *This suggests that the absence of a streaming TV service might be a contributing factor to churn for some customers.*

# %%
plt.figure(figsize=(8,7))
plt.pie(df[df['StreamingTV']=='Yes']['Churn'].value_counts(),labels=df[df['StreamingTV']=='Yes']['Churn'].value_counts().index,autopct='%1.1f%%',startangle=90)
plt.title('Streaming TV Churn')
plt.show()

# %% [markdown]
# **Conclusion:** While a majority `(69.9%)` of customers who opted for streaming TV remained with the service, a notable portion `(30.1%)` still churned. *This suggests that while streaming TV might be a valued service for many, it may not be a strong enough factor on its own to prevent churn for a significant portion of these customers.*

# %% [markdown]
# ### TechSupport vs Churn

# %% [markdown]
# **Reasons for Tech Support vs Churn Analysis:**
#
# - **Assess Support Effectiveness:** Determine if the availability and quality of tech support services are correlated with customer churn.
#
# - **Proactive Customer Retention:** Identify customers at risk of churn due to tech support dissatisfaction and proactively engage them with solutions or improved support experiences.

# %%
print(df['TechSupport'].value_counts())
# Out:
# TechSupport
# No                     3473
# Yes                    2044
# No internet service    1526
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,7))
sns.histplot(x=df['TechSupport'],hue=df['Churn'],multiple="dodge",shrink=.8)
plt.title('Tech Support vs Churn')
plt.show()

# %% [markdown]
# - We can observe that customers who are not availed TechSupport churned more.
#
#
# > Let's learn more using a pie chart.

# %%
plt.figure(figsize=(8,7))
plt.pie(df[df['TechSupport']=='No']['Churn'].value_counts(),labels=df[df['TechSupport']=='No']['Churn'].value_counts().index,autopct='%1.1f%%',startangle=90)
plt.title('No TechSupport Churn')
plt.show()

# %% [markdown]
# **Conclusion**
#
# While a majority (58.4%) of customers who did not avail tech support remained, a significant portion (41.6%) still churned. To reduce churn, prioritize understanding the reasons behind these customers leaving despite not seeking technical assistance. This could indicate unmet needs or dissatisfaction with other aspects of the service.

# %% [markdown]
# ## Multivar Analysis

# %% [markdown]
# Multivariate analysis is a statistical method that examines the relationships between three or more variables simultaneously. It explores how these variables are associated or correlated with each other, and how they collectively influence a particular outcome or phenomenon.
#
# It goes beyond simple pairwise comparisons and delves into the complex interactions among multiple variables.
#
# In the context of the customer churn dataset, multivariate analysis can help you understand how different factors like demographics, contract type, service usage, and billing information interact to influence a customer's decision to churn.
#
# By considering multiple variables together, you can gain a more comprehensive understanding of the drivers of churn and develop more effective retention strategies.

# %% [markdown]
# ### Tenure By Internet Service Type and Churn

# %%
# Violin plot to show the distribution of a numerical variable across different categories
plt.figure(figsize=(12, 6))
sns.violinplot(x='InternetService', y='tenure', hue='Churn', split=True, data=df)
plt.title('Tenure by Internet Service Type and Churn')
plt.show()

# %% [markdown]
# The violin plot shows the distribution of the tenure of customers based on their internet service type (DSL, Fiber optic, or No internet service) and whether they churned (Yes or No).
#
# > **Observations and Conclusions:**
#
# 1. **DSL:**
#    - **Churn (Yes):** Customers who churned tend to have lower tenure, with a peak at the lower end of the tenure spectrum.
#    - **Churn (No):** Customers who did not churn have a wider distribution, with peaks both at lower and higher tenures.
#
# 2. **Fiber Optic:**
#    - **Churn (Yes):** Similar to DSL, customers who churned generally have lower tenure.
#    - **Churn (No):** Customers who did not churn are distributed across a wider range of tenures, with a significant number having high tenure.
#
# 3. **No Internet Service:**
#    - **Churn (Yes):** The distribution for customers who churned is concentrated at lower tenures.
#    - **Churn (No):** Customers who did not churn are distributed across a wider range of tenures, with more significant peaks at both low and high tenures.
#
# > **Conclusion:**
# - **Tenure and Churn:** Across all internet service types, customers with lower tenures are more likely to churn, while those with higher tenures tend to stay.
# - **Service Type Differences:** There are no significant differences in the churn patterns between customers using DSL and Fiber optic. However, those without internet service have a similar distribution pattern regarding churn.
#
# > **Implications:**
# - **Retention Strategies:** Focus on increasing the tenure of customers could be a key strategy in reducing churn.
# - **Customer Support and Engagement:** Early engagement and support for new customers might help in reducing churn rates, as customers with lower tenures are more likely to churn.
#
# This analysis can guide targeted interventions to improve customer retention based on their tenure and type of internet service.

# %% [markdown]
# ### Monthly Charges by Contract Type and Churn

# %% [markdown]
# - This plot will show the distribution of monthly charges for different contract types and how it relates to customer churn.
# - We expect to see if higher or lower monthly charges influence churn across different contract types.

# %%
# Monthly Charges by Contract Type and Churn
plt.figure(figsize=(12, 6))
sns.violinplot(x='Contract', y='MonthlyCharges', hue='Churn', split=True, data=df)
plt.title('Monthly Charges by Contract Type and Churn')
plt.show()

# %% [markdown]
# The violin plot shows the distribution of monthly charges for customers based on their contract type (Month-to-month, One year, Two year) and whether they churned (Yes or No).
#
# > **Observations and Conclusions:**
#
# 1. **Month-to-Month Contract:**
#    - **Churn (Yes):** Customers who churn tend to have a slightly higher monthly charge, with a peak around $70 to $100.
#    - **Churn (No):** Customers who do not churn have a broader distribution, with peaks around $20 to $40 and $60 to $90.
#
# 2. **One Year Contract:**
#    - **Churn (Yes):** Customers who churn have a wide distribution of monthly charges, similar to those who do not churn, but the peak is slightly higher.
#    - **Churn (No):** Customers who do not churn have a distribution peaking around $20 to $50 and another peak around $70 to $100.
#
# 3. **Two Year Contract:**
#    - **Churn (Yes):** There are fewer customers who churn with a two-year contract, but they tend to have a higher monthly charge, peaking around $70 to $100.
#    - **Churn (No):** Customers who do not churn have a wider distribution, with peaks around $20 to $50 and $60 to $90.
#
# > **Conclusion:**
# - **Monthly Charges and Churn:** Higher monthly charges are associated with a higher likelihood of churn across all contract types.
# - **Contract Type and Churn:** Customers with month-to-month contracts have the highest variability in monthly charges and churn rates. Longer contracts (one year and two years) have fewer customers who churn, suggesting that longer commitments may help reduce churn.
# - **Retention Strategies:** To reduce churn, consider offering incentives or discounts for longer contracts, especially for customers with higher monthly charges. Addressing the higher churn rate in month-to-month contracts by improving customer satisfaction and loyalty programs might also help.
#
# > **Implications:**
# - **Targeted Interventions:** Focus on customers with higher monthly charges for targeted interventions to reduce churn.
# - **Contract Promotions:** Encourage customers to switch to longer-term contracts with attractive promotions and benefits.
# - **Customer Support:** Provide additional support and engagement for month-to-month customers to improve retention rates.
#
# These insights can help in designing strategies to improve customer retention and reduce churn based on monthly charges and contract types.

# %% [markdown]
# ### Total Charges by Payment Method and Churn

# %% [markdown]
# - This plot will display the distribution of total charges for different payment methods and their relationship to churn.
# - It helps to understand if certain payment methods are associated with higher churn rates.

# %%
# Total Charges by Payment Method and Churn
plt.figure(figsize=(12, 6))
sns.violinplot(x='PaymentMethod', y='TotalCharges', hue='Churn', split=True, data=df)
plt.title('Total Charges by Payment Method and Churn')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The chart is a violin plot displaying the distribution of total charges by different payment methods and churn status. Here are the key points:
#
# 1. **Electronic Check**:
#    - Customers who churned (orange) have a higher density of lower total charges compared to those who did not churn (blue).
#    - The distribution of charges for non-churned customers is wider, indicating a broader range of total charges.
#
# 2. **Mailed Check**:
#    - There is a significant overlap between the churned and non-churned customers, but non-churned customers seem to have slightly higher total charges.
#    - The distribution is narrower compared to electronic check, suggesting less variation in total charges.
#
# 3. **Bank Transfer (automatic)**:
#    - Non-churned customers have a higher density of higher total charges.
#    - Churned customers have a relatively lower total charges distribution.
#
# 4. **Credit Card (automatic)**:
#    - Similar to bank transfer, non-churned customers have a higher density of higher total charges.
#    - Churned customers have lower total charges distribution.
#
# **Conclusion**:
# - Customers paying by electronic check have a higher tendency to churn compared to other payment methods.
# - Automatic payment methods (bank transfer and credit card) are associated with higher total charges and lower churn rates.
# - Mailed checks show a less distinct difference between churned and non-churned customers in terms of total charges.

# %% [markdown]
# ### Tenure by Contract Type and Churn

# %% [markdown]
# - This plot will show how tenure varies with different contract types and how it impacts churn.
# - We can see if longer tenures are associated with certain contract types and whether they help in reducing churn.

# %%
# Tenure by Contract Type and Churn
plt.figure(figsize=(12, 6))
sns.violinplot(x='Contract', y='tenure', hue='Churn', split=True, data=df)
plt.title('Tenure by Contract Type and Churn')
plt.show()
